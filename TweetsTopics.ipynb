# %% [markdown]
# # Using topic modeling to look into frequent topics in negative and positive Tweets

# %%
import pandas as pd
import numpy as np
import string
import sys
import re

#text processing, NLP modules
import string
import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import *
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize

import gensim.downloader
from gensim.models import KeyedVectors
from gensim.models import Word2Vec

import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (15, 10)

# %%
#!pip install python-Levenshtein

# %% [markdown]
# # Topics negative tweets

# %% [markdown]
# ## Import negative tweets labeled by VADER

# %%
df = pd.read_csv('Data/tweety_topic.csv')
df_tweety = df

# %% [markdown]
# ### Cleaning, feature engineering for negative

# %%
def clean_again(x):
    x = str(x)
    x = x.lower()
    x = x.split()

    return x

# %%
import random
text_data = []
for tweet in df_tweety.text:
    tokens = clean_again(tweet)
    if random.random() > .99:
        print(tokens)
        text_data.append(tokens)
# Out:
# ['poison', 'enough', 'left', 'side', 'effect', 'like', 'flocking']
# ['alaskan', 'healthcare', 'worker', 'suffers', 'severe', 'allergic', 'reaction', 'covid', 'vaccine']
# ['people', 'required', 'get', 'unwanted', 'vaccine', 'people', 'also', 'required', 'maintain', 'unwanted', 'pregnancy']
# ['hearing', 'story', 'people', 'allergic', 'reaction', 'pfizer', 'biontech', 'covid']
# ['need', 'answer', 'serious', 'question', 'continuing']
# ['pharmaceutical', 'company', 'victim']
# ['heard', 'today', 'people', 'refusing', 'want', 'british', 'one']
# ['buckle', 'buttercup', 'second', 'dose', 'bear', 'misgiving', 'mild', 'side', 'effect']
# ['worrying', 'death', 'portuguese', 'nursedays', 'receiving', 'vaccine', 'also', 'went', 'mostly']
# ['sick', 'amp', 'tired', 'ot', 'virologist', 'amp', 'scientific', 'professional', 'going', 'broadcast', 'medium', 'say', 'nothi']
# ['2nd', 'ill', 'hour', 'like', 'bad', 'vaccin']
# ['first', 'vaccine', 'dosage', 'today', 'needle', 'say', 'someone', 'always', 'reacts', 'injection', 'absolutely', 'shit']
# ['btw', 'significant', 'injection', 'site', 'pain', 'little', 'surprised', 'hear', 'gotten', 'th']
# ['second', 'shot', 'joke', 'worse', 'headache', 'long', 'remember', 'spentday', 'bed', 'second']
# ['hour', 'post', 'moderately', 'sore', 'shoulder', 'really', 'lifting', 'rotating']
# ['doug', 'ford', 'trudeau', 'destroy', 'toronto', 'ontario', 'canada']
# ['snooze', 'lose']
# ['inactivated', 'whole', 'virion', 'vaccine', 'icmr', 'bharat', 'biotech', 'india', 'missing']
# ['new', 'research', 'published', 'microbiology', 'amp', 'infectious', 'disease', 'immunologist', 'j', 'bart', 'classen', 'warns', 'technology', 'u']
# ['global', 'coronavirus', 'death', 'toll', 'reach', '365']
# ['covid', 'vaccine', 'recipient', 'developed', 'rare', 'blood', 'disorder', 'new', 'york', 'time']
# ['world', 'corrupt', 'entity', 'called', 'cia', 'anti', 'vaccine', 'propaganda', 'vaccine', 'essentially']
# ['receiving', '2nd', 'vaccine', 'soon', 'chair', 'felt', 'dizzy', 'resting', 'minu']
# ['european', 'commission', 'said', 'wednesday', 'struck', 'deal', 'extra', 'million', 'dos']
# ['delay', 'shipment', 'due', 'winter', 'weather', 'affecting', '2nd', 'dose', 'appointment', 'rest', 'week', 'de']
# ['wtf', 'glad']
# ['hour', 'vaccine', 'absolutely', 'donald', 'ducked', 'ache', 'pain', 'chill', 'sickness', 'dizziness']
# ['well', 'hiding', 'reaction', 'vaccine', 'last', 'night', 'temp', '39c', 'rigor', 'ache', 'amp']
# ['snap', 'delhi', 'barmer', 'story', 'india', 'huge', 'vaccination', 'drive', 'stubborn', 'vaccine', 'hestitency']
# ['open', 'vaccination', 'everybody', 'dont', 'waste', 'precious', 'vaccine', 'time']
# ['time', 'message', 'cousin', 'disappointed', 'stance']
# ['bitch', 'half', 'way', 'vaccinated']
# ['azn', 'dont', 'infrastructure', 'sale', 'distribute', 'sell', 'mrna', 'mess', 'canada']
# ['oxford', 'az', 'vaccine', 'come', 'significant', 'level', 'unjustified', 'criticism', 'summarise']
# ['european', 'country', 'turning', 'east', 'vaccine', 'amid', 'supply', 'shortage', 'february', 'two', 'week', 'hungary', 'announc']
# ['saturday', 'food', 'drug', 'administration', 'gave', 'emergency', 'authorization', 'third', 'coronavirus', 'vaccine']
# ['clarify', 'doubt']
# ['helped', 'parent', 'get', 'vaccine', 'walgreens', 'tosa', 'shit', 'ton', 'appointment']
# ['number', 'low', 'coz', 'given', 'handful', 'hospital', 'across', 'tn', 'admk', 'govt', 'fear', 'rowdygang', 'dmk', 'would', 'gi']
# ['ok', 'dayarm', 'hurt', 'mild', 'moderate']
# ['trying', 'day', 'starting', '3am', 'get', 'year', 'old', 'mom', 'cancer', 'survivor', 'covid', 'vaccine', 'appointment']
# ['get', '2nd', 'dose', 'moderna', 'tuesday', 'sore', 'arm', '1st', 'dose']
# ['demand', 'grows', 'among', 'indian', 'efficacy', 'result']
# ['russia', 'seek', 'make', 'sputnikitaly', 'overseas', 'demand', 'surge', 'come', 'fruition', 'italy', 'manufacturing']
# ['fascist', 'state', 'introduce', 'wanker', 'exclude', 'im', 'callinga']
# ['worrying', 'outbreak', 'stupidity', 'across', 'europe']
# ['become', 'latest', 'country', 'suspend', 'use', 'coronavirus', 'vaccine', 'co']
# ['narrative', 'imploding', 'life', 'assurance', 'company', 'refusing', 'take', 'risk', 'vaccinat']
# ['vaccinated', 'need', 'worry', 'go']
# ['national', 'aefi', 'committee', 'review', 'week', 'due', 'scare', 'european', 'nation']
# ['sir', 'covid', 'vaccine', 'neither', 'reached', 'pakistan', 'administered', 'peop']
# ['embarrassing', 'ontario', 'reporting', 'case', 'new', 'case', 'toront']
# ['pressured', 'allied', 'country', 'authorize', 'explains', 'bad', 'idea']
# ['1st', 'dose', 'covid', 'vaccine', 'sick', 'head', 'pounding', 'sore', 'throat', 'fever', 'congested', 'ex']
# ['piece', 'failed', 'mention', 'vaccine', 'update', 'please']
# ['biggest', 'shit', 'earth']
# ['msm', 'shouting', 'russia', 'biggest', 'threat', 'highest', 'rooftop', 'could', 'scupper']
# ['beacon', 'light', 'tough', 'year', 'u', 'remembering', 'lost', 'covid', 'thanking']
# ['miss', 'vaccination', 'date', 'second', 'dose', 'due', 'genuine', 'reason', 'mean', 'cant', 'get', 'second', 'dose']
# ['potentially', 'bad', 'news', 'already', 'glacial', 'opaque', 'rollout', 'make', 'baselessly', 'delayed', 'au']
# ['tweeted', 'earlier', 'suspicious', 'anti', 'motif', 'fuelled', 'greed', 'profit', 'ot']
# ['think', 'variant', 'soon', 'big', 'problem', 'everyone', 'need', 'booster', 'latest', 'ocgn']
# ['amp', 'fake', 'everything', 'made', 'fake']
# ['u', 'pressured', 'purchase', 'vaccine']
# ['subject', 'expert', 'committee', 'cdsco', 'likely', 'meet', 'sometime', 'week', 'consider', 'emergency', 'use', 'applicatio']
# ['embarrassing', 'ontario', 'reporting', 'case', 'new', 'case', 'toronto', 'canada', 'politici']
# ['eating', 'alone', 'today', 'doug', 'ford', 'mr', 'trudeau', 'toronto', 'ontario', 'canada', 'forced', 'stay']
# ['china', 'amp', 'russia', 'vaccine', 'defeat', 'cold', 'war', 'virus', 'china', 'ramp', 'supply']
# ['batch', 'fake', 'sputnikvaccines', 'confiscated', 'mexico', 'see', 'comparison', 'genuine']

# %%
from gensim import corpora
dictionary = corpora.Dictionary(text_data)
corpus = [dictionary.doc2bow(text) for text in text_data]
import pickle
pickle.dump(corpus, open('corpus.pkl', 'wb'))
dictionary.save('Data/dictionary.gensim')

# %%
import gensim
NUM_TOPICS = 20
ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics = NUM_TOPICS, id2word=dictionary, passes=15)
ldamodel.save('Data/model5.gensim')

# %%
topics = ldamodel.print_topics(num_words=4)
for topic in topics:
    print(topic)
# Out:
# (0, '0.063*"china" + 0.032*"supply" + 0.032*"cold" + 0.032*"war"')
# (1, '0.022*"tn" + 0.022*"handful" + 0.022*"gi" + 0.022*"fear"')
# (2, '0.057*"dose" + 0.020*"buttercup" + 0.020*"misgiving" + 0.020*"mild"')
# (3, '0.036*"vaccine" + 0.036*"fake" + 0.019*"cia" + 0.019*"anti"')
# (4, '0.067*"ontario" + 0.067*"case" + 0.050*"toronto" + 0.050*"canada"')
# (5, '0.045*"vaccine" + 0.023*"receiving" + 0.023*"also" + 0.023*"went"')
# (6, '0.054*"vaccine" + 0.036*"unwanted" + 0.036*"required" + 0.036*"people"')
# (7, '0.019*"motif" + 0.019*"suspicious" + 0.019*"greed" + 0.019*"earlier"')
# (8, '0.041*"vaccine" + 0.021*"time" + 0.021*"rare" + 0.021*"covid"')
# (9, '0.045*"second" + 0.023*"spentday" + 0.023*"worse" + 0.023*"long"')
# (10, '0.027*"million" + 0.027*"said" + 0.027*"commission" + 0.027*"dos"')
# (11, '0.002*"demand" + 0.002*"among" + 0.002*"grows" + 0.002*"result"')
# (12, '0.040*"vaccine" + 0.020*"delhi" + 0.020*"authorization" + 0.020*"drive"')
# (13, '0.023*"big" + 0.023*"think" + 0.023*"need" + 0.023*"latest"')
# (14, '0.036*"amp" + 0.036*"vaccine" + 0.019*"nothi" + 0.019*"say"')
# (15, '0.027*"dose" + 0.027*"vaccine" + 0.027*"2nd" + 0.014*"weather"')
# (16, '0.038*"vaccine" + 0.020*"february" + 0.020*"supply" + 0.020*"announc"')
# (17, '0.035*"comparison" + 0.035*"sputnikvaccines" + 0.035*"mexico" + 0.035*"batch"')
# (18, '0.046*"vaccine" + 0.031*"dose" + 0.031*"second" + 0.031*"reaction"')
# (19, '0.015*"technology" + 0.015*"u" + 0.015*"research" + 0.015*"microbiology"')

# %%
dictionary = gensim.corpora.Dictionary.load('dictionary.gensim')
corpus = pickle.load(open('corpus.pkl', 'rb'))
lda = gensim.models.ldamodel.LdaModel.load('Data/model5.gensim')

# %% [markdown]
# # Topics positive tweets

# %% [markdown]
# ## Import positive tweets

# %%
df2 = pd.read_csv('Data/tweety_topic2.csv')
df_tweety2 = df2
# Out:
# /Users/christophmichel/.pyenv/versions/3.8.5/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df_tweety2
# Out:
# /Users/christophmichel/.pyenv/versions/3.8.5/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#        Unnamed: 0  index                  user_name  \
# 0               0      0                 Rachel Roh
# 1               2      2                   eli🇱🇹🇪🇺👌
# 2               5      5                        Dee
# 3               6      6          Gunther Fehlinger
# 4               7      7        Dr.Krutika Kuppalli
# ...           ...    ...                        ...
# 15137       38495  38522                     Hilary
# 15138       38498  38525                 Bart Kulpa
# 15139       38500  38527  a street car named Isaiah
# 15140       38511  38538                  Sputnik V
# 15141       38517  38544                  Sputnik V
#
#                      user_location  user_followers  user_friends  \
# 0        La Crescenta-Montrose, CA             405          1692
# 1                         Your Bed              10            88
# 2              Birmingham, England             105           108
# 3      Austria, Ukraine and Kosovo            2731          5001
# 4                              NaN           21924           593
# ...                            ...             ...           ...
# 15137                        Wales             102           116
# 15138                   London, UK            3962          3942
# 15139                          NaN               8            35
# 15140              Moscow, Russia           223700           142
# 15141              Moscow, Russia           223700           142
#
#        user_favourites  user_verified                 date  \
# 0                 3247          False  2020-12-20 06:06:44
# 1                  155          False  2020-12-12 20:33:45
# 2                  106          False  2020-12-12 20:11:42
# 3                69344          False  2020-12-12 20:06:00
# 4                 7815           True  2020-12-12 20:04:29
# ...                ...            ...                  ...
# 15137             4177          False  2021-03-18 09:35:13
# 15138            40988          False  2021-03-18 09:29:21
# 15139               43          False  2021-03-18 09:21:19
# 15140              678           True  2021-03-18 06:47:46
# 15141              678           True  2021-03-18 06:01:50
#
#                                                     text  \
# 0      folk said daikon paste could treat cytokine storm
# 1                    russian vaccine created last 4 year
# 2      doe anyone useful advice guidance whether covi...
# 3      bit sad claim fame success patriotic competiti...
# 4                           many bright day best winning
# ...                                                  ...
# 15137   money getting vaccine true vaccine others mrna g
# 15138  vaccination speed along serbia country basks g...
# 15139  moscow city health department russian direct i...
# 15140  frankfurter allgemeine leader saxony saxony an...
# 15141  austrian chancellor sebastian kurz concerning ...
#
#                                                 hashtags  retweets  favorites  \
# 0                                     ['PfizerBioNTech']         0          0
# 1      ['coronavirus', 'SputnikV', 'AstraZeneca', 'Pf...         0          0
# 2                                                     []         0          0
# 3                                        ['vaccination']         0          4
# 4                        ['BidenHarris', 'Election2020']         2         22
# ...                                                  ...       ...        ...
# 15137                                       ['SPUTNIKV']         1          5
# 15138                                                 []         2          3
# 15139                                                 []         0          0
# 15140                                       ['SputnikV']        92        365
# 15141                                       ['SputnikV']        83        226
#
#               day  user_infl sentiment
# 0      2020-12-20       24.0  positive
# 1      2020-12-12        5.0  positive
# 2      2020-12-12        7.0  positive
# 3      2020-12-12       88.0  positive
# 4      2020-12-12       76.0  positive
# ...           ...        ...       ...
# 15137  2021-03-18       21.0  positive
# 15138  2021-03-18       72.0  positive
# 15139  2021-03-18        3.0  positive
# 15140  2021-03-18      224.0  positive
# 15141  2021-03-18      224.0  positive
#
# [15142 rows x 16 columns]

# %% [markdown]
# ### Cleaning, feature engineering for negative

# %%
def clean_again(x):
    x = str(x)
    x = x.lower()
    x = x.split()

    return x
# Out:
# /Users/christophmichel/.pyenv/versions/3.8.5/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
import random
text_data = []
for tweet in df_tweety2.text:
    tokens = clean_again(tweet)
    if random.random() > .99:
        print(tokens)
        text_data.append(tokens)
# Out:
# ['doe', 'vaccine', 'mean', 'gonna', 'eventually', 'wear', 'proper', 'bra', 'agreement', 'un']
# ['determine', 'still', 'safe', 'effective', 'storage', 'temperature', 'dipped', 'c']
# ['ha', 'appreciated', 'immense', 'undithering']
# ['thanks', 'president', 'reagan']
# ['think', 'need', 'photo', 'booth', 'vaccination', 'site', 'public', 'interest']
# ['likejab', 'go', 'thanks', 'dr', 'ammara', 'hughes', 'vaccinating', 'helping', 'towards', 'target']
# ['give', 'nh', 'staff', 'resource', 'support', 'need', 'tackle', 'health', 'crisis', 'right', 'suppl']
# ['grandad', 'getting', 'first', 'part', 'vaccine', 'tomorrow', 'great', 'scientific', 'achiev']
# ['really', 'excited', 'get', 'today', 'delay', 'mine', 'week', 'cuz', 'service', 'couldnt', 'pr']
# ['covid', 'vaccine', 'thank', 'organised', 'professional', 'service', 'delivery', 'massive', 'cruc']
# ['begin', 'good', 'note', 'pfizer', 'become', 'first', 'covid', 'vaccine', 'approved', 'give', 'green']
# ['welcoming', 'exciting', 'manner', 'happy', 'vaccination', 'day', 'part', 'grateful']
# ['covid', 'vaccine', 'today', 'even', 'phobia', 'needle', 'easy', 'get', 'opportunity', 'please']
# ['going', 'protect', 'frontline', 'police', 'officer', 'continuing', 'work']
# ['guess', 'arrived', 'pizza', 'box', 'number']
# ['anyone', 'care', 'help', 'understand', 'government', 'say', 'okay', 'wait', 'week', 'colleague', 'h']
# ['feeling', 'extremely', 'grateful', 'lucky', 'optimistic', 'received', 'first', 'vaccine', 'wishing', 'everyo']
# ['dear', 'dr', 'would', 'like', 'ask', 'best', 'window', 'administer', 'vaccine']
# ['get', 'chance', 'take', 'vaccine', 'would', 'take', 'thanks', 'colleague']
# ['first', 'dose', 'vaccine', 'today', 'truly', 'impressed', 'see', 'arrangement', 'high', 'prais']
# ['working', 'care', 'pandemic', 'finally', 'thankful', 'grateful']
# ['brilliant', 'news', 'signal', 'commencement', 'mainstream', 'vaccination', 'rollout', 'welldone', 'dedicated']
# ['useful', 'link', 'people', 'created', 'help']
# ['feeling', 'privileged', '1st', 'dose', 'vaccine', 'today', 'huge', 'sense', 'relief', 'euphoria', 'hopef']
# ['vaccine', 'tested', 'politician', 'first', 'survive', 'vaccine', 'safe']
# ['single', 'dose', 'effective', 'second', 'dose', 'around', 'effective']
# ['today', 'received', 'first', 'dose', 'pfizer', 'vaccine', 'many', 'thanks', 'staff']
# ['ceo', 'rory', 'mcgoldrick', 'receiving', 'dosepfizer', 'biontech', 'vaccine', 'courtesy', 'greek', 'national', 'health', 'syste']
# ['bring', 'dad', 'work', 'day', 'glad', 'administer', 'first', 'dose', 'covid', 'vaccine']
# ['student', 'enrolled', 'chinese', 'universitiesstuck', 'pakistan', 'want', 'included', 'priority', 'sinopharm', 'vacc']
# ['created', 'make', 'perfect', 'sense', 'priming', 'might', 'great', 'risk', 'getting', 'experime']
# ['russia', 'coronavirus', 'vaccine', 'safest', 'world', 'maduro', 'say']
# ['choice', 'pfucked', 'u', 'share']
# ['rather', 'world', 'need', 'make', 'film', 'instead', 'pushing', 'narrative', 'like', 'white', 'tiger']
# ['phenomenal', 'event', 'today', 'dozen', 'faith', 'leader', 'district', 'columbia', 'get']
# ['canada', 'stay', 'home', 'police', 'welfare', 'state', 'talk', 'mental', 'health', 'hope', 'god', 'church', 'freedom', 'fam']
# ['u', 'secures', 'million', 'dos', 'moderna', 'pfizer', 'covid', 'vaccine']
# ['vaccine', 'receive', 'vaccine', 'pfizer', 'moderna', 'money', 'pay', 'please', 'make', 'u']
# ['fully', 'thank']
# ['mrna', 'ha', 'excellent', 'analysis', 'score', 'fa', 'score', 'check', 'various', 'fa', 'indicator', 'value', 'score']
# ['behold', 'another', 'stroke', 'genius', 'love']
# ['hi', 'know', 'day', 'result', 'announced', 'thanks']
# ['20th', 'day', 'first', 'shot', 'yesterday', 'already', 'antibody', '7', 'positive']
# ['good', 'news', 'chance', 'take', 'look']
# ['case', 'missed', 'work', 'science', 'behind', 'make', 'highly', 'effective']
# ['president', 'thanks', 'supply', 'vaccine']
# ['confirmed', 'equally', 'effective', 'uk', 'original', 'heterogen']
# ['announced', 'agreement', 'supply', 'additional', 'million', 'dos']
# ['get', 'gift', '000', 'dos', 'china', 'also', 'willing', 'provide']
# ['fast', 'track', 'approval']
# ['approved']
# ['good', 'cried', 'year', 'ago', 'world', 'started', 'see', 'first', 'sign']
# ['first', 'batch', 'china', 'sinovac', 'vaccine', 'arrived', 'bangkok', 'wednesday', 'welcomed', 'thai', 'prime', 'minist']
# ['dramatically', 'increase', 'vaccine', 'production', 'spring']
# ['received', '1st', 'covid', 'vaccine', 'thanks', 'terrell', 'isd']
# ['happy', 'happy', 'return', 'day']
# ['india', 'great']
# ['important', 'note', 'modi', 'ji', 'took', 'made', 'india']
# ['entertaining', 'fact', 'better', 'eua', 'approved', 'vaccine', 'like', 'covaxin', 'b']
# ['still', 'holding', 'true', 'believer', 'vaccine', 'need', 'strain', 'age']
# ['approved', 'russia', 'vaccine', 'becoming', '34th', 'country', 'outside', 'russia', 'third', 'north', 'afri']
# ['first', 'dose', 'pfizer', 'covid', 'vaccine', 'please', 'get', 'soon', 'eligible', 'beat', 'disease', 'sav']
# ['vaccine', 'safe', 'believe', 'fact', 'professional', 'lie', 'local', 'drunkard', 'call']
# ['today', 'beautifully', 'sunny', 'morning', 'happyrelieved', 'live', 'autoimmune', 'disease']
# ['mrna', 'moderna', 'transformative', 'financial', 'year', 'group', 'gt', 'guidance', 'well', 'ahead', 'expectat']
# ['technology', 'significant', 'development', 'senior', 'analyst', 'discus']
# ['thanks']
# ['get', 'elder', 'vaccinated', 'keep', 'safe', 'healthy']
# ['k', 'dmitriev', 'rdif', 'ceo', 'important', 'milestone', 'today', '1', 'bln', 'people', 'live', 'country', 'got']
# ['deactivated', 'virus', 'based', 'safe', 'unlike', 'yr', 'never', 'successf']
# ['ok', 'start', 'conversation', 'vaccine', 'amazing', 'saying']
# ['best', 'tweet', 'read', 'leading', 'front', 'jab']
# ['must', 'taken', 'redbull', 'instead', 'safe', 'side']
# ['proud', 'moment', 'incredible', 'thank', 'showing', 'rest', 'world', 'india']
# ['give', 'number', 'front', 'world', 'efficient', 'amp', 'effective']
# ['kuyas', 'part', 'phil', 'heart', 'center', 'first', 'covid', 'vaccine', 'rollout', 'adverse', 'side', 'effect', 'far']
# ['america', 'want']
# ['excited', 'today', 'thanks', 'let', 'protect']
# ['great', 'win', 'atmanirbhar', 'bharat', 'india', 'indigenously', 'developed', 'show', 'interim', 'efficacy', 'phaset']
# ['effective']
# ['prevents', 'covid', 'preventing', 'serious', 'illness', 'u', 'ha', 'massaged', 'efficacy', 'definition', 'suit', 'le', 'effective']
# ['good', 'work', 'team', 'bharat', 'biotech', 'covaxin', 'found', 'effective']
# ['interim', 'result', 'encouraging', 'dr', 'randeep', 'guleria', 'phaseclinical', 'trial', 'result']
# ['good', 'protocol', 'changed', 'trying', 'keep', 'u', 'safe']
# ['approved', 'emergency', 'use', 'country', 'around', 'world', 'ex']
# ['min', 'flat', 'done', 'thank', 'doctor', 'healthcare', 'staff', 'shri']
# ['sputnikworld', 'second', 'popular', 'term', 'reg']
# ['canada', 'approved', 'sputnik', 'v', 'world', 'second', 'popular']
# ['arrival', 'vaccine', 'promise', 'return', 'life', 'created', 'market', 'worth', 'ten']
# ['feel', 'blessed', 'received', 'first', 'jab', 'today', 'thanks', 'school', 'district', 'city', 'health', 'dept', 'holding', 'clin']
# ['already', 'approved', 'assessed', 'approval', 'member', 'state']
# ['new', 'study', 'warns', 'vaccine', 'could', 'far', 'le', 'effective', 'variant']
# ['really', 'hope', 'happen']
# ['covaxin', 'showed', 'better', 'reactogenicity', 'safety', 'outcome', 'phasetrials', 'phasetrials']
# ['pharmaniaga', 'lifescience', 'sdn', 'bhd', 'pls', 'wholly', 'owned', 'subsidiary', 'pharmaniaga', 'entered', 'local', 'manufactur']
# ['made', 'point', 'see', 'allow', 'piggy', 'back', 'new', 'mrna', 'lipid', 'vector', 'wil']
# ['yes', 'ordered', 'vanilla', 'pudding', 'red', 'velvet', 'cheesecake', 'magnolia', 'bakery', 'shot', 'done']
# ['pleased']
# ['good', 'news', 'announced', 'first', 'study', 'volunteer', 'received', 'modified', 'covid', 'vaccine', 'design']
# ['good', 'day']
# ['year', 'old', 'healthy', 'utah', 'mother', 'dy', 'taking', 'second', 'dose', 'moderna', 'vaccine', 'four', 'day', 'taking', 'second']
# ['accompanied', 'father', 'get', 'second', 'dose', 'covid', 'vaccine', 'yesterday', 'feel', 'happy', 'thank']
# ['year', 'old', 'mamaji', 'vaccinated', 'today', 'vaccine', 'game', 'changer', 'new', 'light', 'positivity']
# ['recently', 'published', 'result', 'phase', 'trial', 'cleared', 'another', 'hurdle']
# ['today', 'wake', 'roughly', 'hour', 'jab', 'team', 'smile', 'slight', 'tenderness']
# ['2nd', 'dose', 'covaxin', 'successful', '03', '11']
# ['seamless', 'efficient', 'well', 'organized', 'well', 'executed', 'kudos', 'outstanding', 'service']
# ['really', 'appreciate', 'someone', 'took', 'time', 'give', 'information', 'actually', 'pertinent']
# ['thank', 'heather', 'team', 'first']
# ['covid', 'vaccine', 'fda', 'approved', 'fda', 'authorized', 'use', 'vaccine', 'eua', 'emergency']
# ['vaccine', 'tracker', 'covid', 'share', 'injection', 'region', 'moderna', 'italy', 'date']
# ['thankful', 'gotten', 'first', 'covid', 'vaccination', 'shot', 'today', 'thank']
# ['zenit', 'vaccination', 'programme', 'even', 'getting', 'good', 'headline', 'usa']
# ['thread', 'nobody', 'want', 'guinea', 'pig', 'france', 'high']
# ['thing', 'clda', 'done', 'way', 'better', 'shirt', 'team', 'visor', 'brack']
# ['never', 'stoked', 'severe', 'asthmatic', 'entire', 'life', 'thank', 'science']
# ['brilliant', 'suspension', 'around', 'globe']
# ['europe', 'medicine', 'regulator', 'attempting', 'reassure', 'country', 'stopped', 'using']
# ['coverage', 'indiaam', '03', 'total', 'beneficiary', 'vaccinated', '50', '536', '17']
# ['course', 'proven', 'safe', 'kid', 'research', 'backing']
# ['reason', 'nz', 'govt', 'amp', 'pharmac', 'used', 'cheaper', 'effective', 'vaccine']
# ['first', 'shot', 'yesterday', 'feeling', 'pretty', 'good', 'sore', 'arm', 'showed', 'hour', 'shot', 'little']
# ['jus', 'like', 'bullsh', 'ting', 'vaccine']
# ['effective']
# ['go', 'get', 'sars', 'cov', 'vaccine', 'number', 'one', 'gundersen', 'st', 'j']
# ['montgomery', 'county', 'health', 'department', 'expands', 'covid', 'vaccination', 'eligibility']
# ['well', 'easy', 'dunn', 'north', 'carolina']
# ['thank', 'helping', 'fund', 'miracle', 'vaccine', 'yes', 'wore', 'shirt', 'spec']
# ['vaccine', '95', 'percent', 'effective', 'percent', 'risk', 'still', 'warran']
# ['got', '2nd', 'shot', 'yesterday', 'luckily', 'feel', 'sick', 'feel', 'like', 'woke', 'year', 'older']
# ['case', 'wondering', 'know', 'wa', 'yes', 'guy', 'already', 'done', 'song', 'called']
# ['fucking', 'beautiful', 'day', 'first', 'jab']
# ['excited', 'able', 'secure', 'appointment', 'first', 'morning', 'wednesday']
# ['rich', 'country', 'hoarding', 'amp', 'china', 'allowing', 'entry', 'w', 'h']
# ['many', 'allergy', 'food', 'pet', 'antibiotic', 'included', 'want', 'take']
# ['nice', 'morning', '1st', 'covid', 'vaccine', 'shot']
# ['shot', 'effective', 'urge', 'get', 'dos', 'pfizer', 'evenshot', 'ei']
# ['many', 'kid', 'named', 'thanks']
# ['let', 'see', 'mutant', 'power', 'get', 'thank', 'saving', 'future', 'life', 'may', 'al']
# ['received', 'first', 'covid', 'vaccine', 'shot', 'excited']
# ['lucky', 'one', 'receive', 'first', 'jab', 'yesterday', 'thank', 'lovely', 'staff']
# ['happy', 'spring', 'everyone', 'hour', 'jab', 'yesterday', 'feel', 'great', 'thing', 'report']
# ['sad', 'family', 'mum', 'still', 'young', 'agree', 'please', 'everyo']
# ['someone', 'created', 'vaccine', 'without', 'bank', 'mrna', 'tech', 'person', 'belongs', 'key', 'sue']
# ['first', 'dose', 'vaccine', 'done', 'set', 'carmichael', 'hall', 'giffnock', 'staff', 'fantastic']
# ['got', 'first', 'dose', 'thanks']
# ['india', 'decided', 'extend', 'interval', 'dos', 'covid', 'vaccine', 'eight', 'week', 'h']
# ['give', 'emergency', 'use', 'approval']
# ['give', 'number', 'front', 'world', 'efficient', 'amp', 'effective']
# ['serum', 'institute', 'join', 'stride', 'gland', 'sputnikflight', 'virchow', 'million', 'rdif', 'tied', 'arou']
# ['please', 'stop', 'whining', 'scrificing', 'thousend', 'european', 'expedite', 'approval']
# ['state', 'minister', 'production', 'supply', 'regulation', 'pharmaceutical', 'prof', 'jayasumana', 'said', 'cabinet', 'approval']
# ['wow', 'really', 'run', 'kidding', 'obviously', 'reality', 'eu', 'need']
# ['german', 'would', 'choose', 'vaccinated', 'provided', 'receives', 'approval', 'european']
# ['maybe', 'approach', 'russia', 'vaccine', 'said', 'vaccine', 'hope', 'hav']
# ['million', 'dos', 'contract', 'million', 'dos', 'agreement', 'come', 'new', 'one']
# ['eu', 'probably', 'help', 'russia', 'vaccine', 'commissioner', 'say']
# /Users/christophmichel/.pyenv/versions/3.8.5/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
from gensim import corpora
dictionary = corpora.Dictionary(text_data)
corpus = [dictionary.doc2bow(text) for text in text_data]
import pickle
pickle.dump(corpus, open('corpus.pkl', 'wb'))
dictionary.save('Data/dictionary.gensim')
# Out:
# /Users/christophmichel/.pyenv/versions/3.8.5/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
import gensim
NUM_TOPICS = 20
ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics = NUM_TOPICS, id2word=dictionary, passes=15)
ldamodel.save('Data/model5.gensim')
# Out:
# /Users/christophmichel/.pyenv/versions/3.8.5/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
topics = ldamodel.print_topics(num_words=4)
for topic in topics:
    print(topic)
# Out:
# (0, '0.033*"vaccine" + 0.025*"thank" + 0.016*"jab" + 0.016*"one"')
# (1, '0.015*"right" + 0.015*"tackle" + 0.015*"staff" + 0.015*"health"')
# (2, '0.014*"vaccine" + 0.014*"relief" + 0.014*"hopef" + 0.014*"huge"')
# (3, '0.025*"vaccine" + 0.025*"phasetrials" + 0.025*"covaxin" + 0.025*"better"')
# (4, '0.053*"vaccine" + 0.048*"first" + 0.048*"covid" + 0.017*"effective"')
# (5, '0.022*"today" + 0.022*"vaccine" + 0.022*"first" + 0.011*"got"')
# (6, '0.019*"approval" + 0.010*"shot" + 0.010*"first" + 0.010*"ha"')
# (7, '0.036*"good" + 0.024*"thanks" + 0.024*"shot" + 0.024*"first"')
# (8, '0.070*"effective" + 0.028*"give" + 0.028*"efficient" + 0.028*"amp"')
# (9, '0.052*"vaccine" + 0.043*"thanks" + 0.026*"score" + 0.017*"take"')
# (10, '0.024*"vaccine" + 0.024*"thanks" + 0.016*"pharmaniaga" + 0.016*"well"')
# (11, '0.022*"health" + 0.022*"vaccination" + 0.011*"dosepfizer" + 0.011*"courtesy"')
# (12, '0.028*"million" + 0.028*"dos" + 0.028*"happy" + 0.014*"agreement"')
# (13, '0.027*"approved" + 0.018*"see" + 0.018*"result" + 0.018*"world"')
# (14, '0.068*"vaccine" + 0.031*"covid" + 0.013*"second" + 0.013*"taking"')
# (15, '0.026*"vaccine" + 0.017*"covid" + 0.017*"first" + 0.017*"today"')
# (16, '0.036*"vaccine" + 0.024*"getting" + 0.024*"great" + 0.024*"percent"')
# (17, '0.019*"game" + 0.019*"light" + 0.019*"mamaji" + 0.019*"positivity"')
# (18, '0.051*"vaccine" + 0.021*"shot" + 0.016*"feel" + 0.016*"like"')
# (19, '0.015*"state" + 0.015*"talk" + 0.015*"hope" + 0.015*"stay"')
# /Users/christophmichel/.pyenv/versions/3.8.5/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
